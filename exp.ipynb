# %% [markdown]
# <a href="https://colab.research.google.com/github/jai-Lykaios/deep_learning/blob/main/exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SIMPLE CNN FOR BINARY IMAGE CLASSIFICATION
# Cats vs Dogs

# !pip install -q gdown

import gdown

file_id = "14zAvLt1t-CMB0iXtNPZjh90Y6FHzKbn1"

url = f"https://drive.google.com/uc?id={file_id}"

gdown.download(
    url,
    "cats_and_dogs_filtered.zip",
    quiet=False
)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=14zAvLt1t-CMB0iXtNPZjh90Y6FHzKbn1
# From (redirected): https://drive.google.com/uc?id=14zAvLt1t-CMB0iXtNPZjh90Y6FHzKbn1&confirm=t&uuid=abda5d6d-13ba-4a75-bd4e-67d05b62c0e5
# To: /content/cats_and_dogs_filtered.zip
# 100%|██████████| 137M/137M [00:02<00:00, 66.2MB/s]
# 'cats_and_dogs_filtered.zip'

# %%
import zipfile

with zipfile.ZipFile("cats_and_dogs_filtered.zip", "r") as zip_ref:
    zip_ref.extractall("/content")

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
import os

base_dir = "/content/cats_and_dogs_filtered"

train_dir = os.path.join(base_dir, "train")
validation_dir = os.path.join(base_dir, "validation")

print("Train:", train_dir)
print("Validation:", validation_dir)
# Out:
# Train: /content/cats_and_dogs_filtered/train
# Validation: /content/cats_and_dogs_filtered/validation

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import zipfile
import os


# !pip install -q gdown

import gdown

file_id = "14zAvLt1t-CMB0iXtNPZjh90Y6FHzKbn1"

url = f"https://drive.google.com/uc?id={file_id}"

gdown.download(
    url,
    "cats_and_dogs_filtered.zip",
    quiet=False
)


with zipfile.ZipFile("cats_and_dogs_filtered.zip", "r") as zip_ref:
    zip_ref.extractall("/content")

print("Dataset extracted successfully!")


base_dir = "/content/cats_and_dogs_filtered"

train_dir = os.path.join(base_dir, "train")
validation_dir = os.path.join(base_dir, "validation")

print("Train:", train_dir)
print("Validation:", validation_dir)

train_data = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(128, 128),
    batch_size=32,
    shuffle=True
)

val_data = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(128, 128),
    batch_size=32,
    shuffle=False
)

print("Classes:", train_data.class_names)


# --------------------------------------------------
# 6. Build CNN Model
# --------------------------------------------------

model = models.Sequential([

    # Normalize pixel values
    layers.Rescaling(1./255,
                     input_shape=(128, 128, 3)),

    # First Convolution Layer
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Second Convolution Layer
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Third Convolution Layer
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Flatten
    layers.Flatten(),

    # Fully Connected Layer
    layers.Dense(128, activation='relu'),

    # Binary Classification Output
    layers.Dense(1, activation='sigmoid')
])


# --------------------------------------------------
# 7. Display CNN Model
# --------------------------------------------------

model.summary()


# --------------------------------------------------
# 8. Compile the Model
# --------------------------------------------------

model.compile(
    optimizer='SGD',
    loss='binary_crossentropy',
    metrics=['accuracy']
)


# --------------------------------------------------
# 9. Train the CNN
# --------------------------------------------------

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)


# --------------------------------------------------
# 10. Evaluate the Model
# --------------------------------------------------

loss, accuracy = model.evaluate(val_data)

print("Validation Loss:", loss)
print("Validation Accuracy:", accuracy)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=14zAvLt1t-CMB0iXtNPZjh90Y6FHzKbn1
# From (redirected): https://drive.google.com/uc?id=14zAvLt1t-CMB0iXtNPZjh90Y6FHzKbn1&confirm=t&uuid=1fb6e917-de8a-4b8e-bb6b-c16a2a485eb6
# To: /content/cats_and_dogs_filtered.zip
# 100%|██████████| 137M/137M [00:01<00:00, 68.7MB/s]
# Dataset extracted successfully!
# Train: /content/cats_and_dogs_filtered/train
# Validation: /content/cats_and_dogs_filtered/validation
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Classes: ['cats', 'dogs']
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,304,769 (12.61 MB)
#  Trainable params: 3,304,769 (12.61 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.5025 - loss: 0.6941 - val_accuracy: 0.5610 - val_loss: 0.6881
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.5465 - loss: 0.6885 - val_accuracy: 0.5720 - val_loss: 0.6842
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.5540 - loss: 0.6847 - val_accuracy: 0.5050 - val_loss: 0.6927
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.5550 - loss: 0.6826 - val_accuracy: 0.5630 - val_loss: 0.6784
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.5865 - loss: 0.6777 - val_accuracy: 0.5620 - val_loss: 0.6777
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.5955 - loss: 0.6728 - val_accuracy: 0.6040 - val_loss: 0.6689
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.5885 - loss: 0.6727 - val_accuracy: 0.5220 - val_loss: 0.6823
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.6005 - loss: 0.6654 - val_accuracy: 0.5690 - val_loss: 0.6749
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.6010 - loss: 0.6612 - val_accuracy: 0.6010 - val_loss: 0.6646
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.6175 - loss: 0.6536 - val_accuracy: 0.6060 - val_loss: 0.6547
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 318ms/step - accuracy: 0.6060 - loss: 0.6547
# Validation Loss: 0.6546997427940369
# Validation Accuracy: 0.6060000061988831
